# %%
#CELDA IMPORTANTE NO TOCAR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# Opciones visualización
pd.set_option('display.max_columns', None)
sns.set(style="whitegrid")

# %%
import matplotlib.pyplot as plt
import missingno as msno
import pandas as pd

# Cargar dataset
dino_df = pd.read_csv("../data/01_raw/prehistoric_dinosaur_profiles.csv")

# Información general
print(dino_df.shape)
print(dino_df.dtypes)
print(dino_df.head())

# Resumen valores faltantes
print(dino_df.isnull().sum())
print(dino_df.isnull().mean() * 100)

# Visualización de missing values con tamaño controlado
msno.matrix(dino_df, figsize=(10,4))   # ancho 10, alto 4
plt.show()

msno.heatmap(dino_df, figsize=(8,4))  # ancho 8, alto 4
plt.show()

# Estadísticas básicas
print(dino_df.describe(include='all'))

# Comentarios y hallazgos
# Valores nulos leves en algunas columnas, tipos de datos correctos.
# Las distribuciones de clases se pueden analizar para identificar posibles sesgos.
# Out:
# (15000, 11)
# diet_type             object
# situation             object
# emotion_state         object
# group_status          object
# time_of_day           object
# dino_name             object
# activity_level        object
# size_class            object
# social_requirement    object
# active_period         object
# threat_level          object
# dtype: object
#    diet_type  situation emotion_state    group_status time_of_day  \
# 0  Carnivore     hungry       fearful           alone     morning
# 1  Carnivore       calm      insecure           alone       night
# 2  Herbivore  defensive       fearful  with_juveniles     evening
# 3   Omnivore      alert      dominant       with_mate     evening
# 4  Herbivore    wounded    aggressive           alone       night
#
#      dino_name activity_level size_class social_requirement active_period  \
# 0  spinosaurus           high     medium               solo        diurno
# ...
